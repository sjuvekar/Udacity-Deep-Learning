# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5243, 3082, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of', 'abuse', 'term', 'first', 'of', 'abuse', 'used', 'against', 'first']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of']
#     labels: ['term', 'originated', 'a', 'anarchism', 'of', 'originated', 'as', 'term', 'of', 'abuse', 'as', 'a', 'a', 'abuse', 'term', 'first']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.127722
# Nearest to four: furlongs, episkopos, menthol, collaborators, duffy, unavailable, rotting, weidenfeld,
# Nearest to i: homeopathic, libertarian, sampling, tires, aoun, syracuse, collectives, hillsdale,
# Nearest to up: antinous, rhineland, curry, uplift, returns, eccentricities, hodge, astrologer,
# Nearest to at: marinetti, rmi, monophyletic, webelements, monophysite, investments, livre, impacting,
# Nearest to it: paints, livia, xxix, haste, aboriginal, alive, bathe, chromium,
# Nearest to d: comedic, dso, dispersive, mcnamara, pompeii, pt, patria, kk,
# Nearest to an: confidence, dye, hyperplasia, insulating, binge, foederati, jarre, ardal,
# Nearest to first: intermediates, grade, shing, semivowel, honored, flaminius, autistic, watchers,
# Nearest to while: wwi, ishiro, determinative, sintering, observance, polaris, accessed, gregory,
# Nearest to during: disguise, grilled, gomer, nh, caption, february, cooperating, permitted,
# Nearest to zero: headings, frenchmen, correspondent, hizballah, oran, moral, cathedrals, rams,
# Nearest to world: cavendish, terabytes, mixes, tanzania, insular, iff, elwes, exxonmobil,
# Nearest to but: mild, intelligibility, monkey, gilliam, multiplies, venue, misogynist, garde,
# Nearest to in: cannery, peloponnesian, impossible, avl, romanesque, offset, festus, pigs,
# Nearest to known: woodward, libi, wrestlemania, bondi, nevis, toulon, monk, flywheel,
# Nearest to b: shock, rest, poking, nucleophilic, wheeled, farther, longwave, infrequently,
# Average loss at step 2000: 4.355206
# Average loss at step 4000: 3.869116
# Average loss at step 6000: 3.784401
# Average loss at step 8000: 3.692287
# Average loss at step 10000: 3.612725
# Nearest to four: six, three, eight, five, seven, nine, two, zero,
# Nearest to i: they, mohandas, homeopathic, weu, pots, akad, divisor, mountain,
# Nearest to up: antinous, interests, nashe, fireballs, returns, noree, astrologer, ambassador,
# Nearest to at: in, cheesemaking, with, instigated, monophyletic, lineages, during, prototypical,
# Nearest to it: he, this, there, they, which, not, generally, she,
# Nearest to d: b, remixed, dispersive, xilinx, definite, complaint, mcnamara, victim,
# Nearest to an: joys, purists, described, rangers, dye, huts, the, romans,
# Nearest to first: autistic, underpinning, asquith, fraenkel, barra, comets, semmelweis, galatia,
# Nearest to while: determinative, wwi, polaris, foreground, terre, ensuing, sintering, disposed,
# Nearest to during: in, keller, satirized, smelter, at, caption, prokaryotes, epiphany,
# Nearest to zero: seven, nine, eight, five, six, three, four, two,
# Nearest to world: cavendish, iff, insular, tiergarten, originates, hindu, tanzania, dresden,
# Nearest to but: and, intelligibility, liberate, ibf, stillborn, monkey, mild, every,
# Nearest to in: of, on, at, during, after, with, rabbani, from,
# Nearest to known: well, peaking, nevis, stereotyped, aristocrats, offset, oregano, woodward,
# Nearest to b: shock, d, longwave, loya, morpheus, and, mmo, infrequently,
# Average loss at step 12000: 3.607592
# Average loss at step 14000: 3.575098
# Average loss at step 16000: 3.409277
# Average loss at step 18000: 3.459597
# Average loss at step 20000: 3.542463
# Nearest to four: six, three, five, eight, seven, two, nine, zero,
# Nearest to i: iii, they, ii, we, mohandas, homophony, sampling, scotland,
# Nearest to up: interests, antinous, moved, returns, epr, him, nashe, fireballs,
# Nearest to at: in, with, on, praeger, cheesemaking, from, disk, methylation,
# Nearest to it: he, this, there, they, she, which, generally, surely,
# Nearest to d: b, cluster, bacharach, remixed, supernaturally, pt, cheerfully, busway,
# Nearest to an: the, joys, binge, huts, romans, cybele, jeb, purists,
# Nearest to first: second, underpinning, asquith, fraenkel, same, autistic, next, rourke,
# Nearest to while: wwi, terre, foreground, ensuing, ogilvie, determinative, disposed, transcontinental,
# Nearest to during: keller, following, in, satirized, lokasenna, caption, smelter, after,
# Nearest to zero: six, five, seven, four, three, nine, eight, two,
# Nearest to world: cavendish, tiergarten, iff, terabytes, tanzania, conjectures, hindu, insular,
# Nearest to but: however, and, that, is, which, when, though, although,
# Nearest to in: at, on, from, with, during, tanganyika, and, controllable,
# Nearest to known: well, stereotyped, peaking, such, nevis, just, oregano, aristocrats,
# Nearest to b: d, loya, suing, mmo, bluegrass, shock, longwave, gundobad,
# Average loss at step 22000: 3.502592
# Average loss at step 24000: 3.489533
# Average loss at step 26000: 3.477159
# Average loss at step 28000: 3.476928
# Average loss at step 30000: 3.500131
# Nearest to four: five, three, six, eight, seven, two, nine, zero,
# Nearest to i: iii, we, ii, they, homophony, mohandas, sampling, doyle,
# Nearest to up: him, down, epr, out, interests, them, returns, policing,
# Nearest to at: in, on, during, controllable, viewpoints, cheesemaking, highlander, monarchy,
# Nearest to it: he, this, there, she, they, not, tumbling, which,
# Nearest to d: b, remixed, pt, cluster, bacharach, cheerfully, reinforce, boece,
# Nearest to an: dye, golgi, lk, palpitations, insulating, rangers, booch, joys,
# Nearest to first: second, same, underpinning, next, beowulf, multipoint, last, prisma,
# Nearest to while: wwi, is, ensuing, transcontinental, schizophrenic, disposed, ogilvie, terre,
# Nearest to during: after, in, at, keller, lokasenna, yuma, throughout, satirized,
# Nearest to zero: eight, five, seven, four, six, nine, three, two,
# Nearest to world: iff, cavendish, insular, hindu, tanzania, advances, tiergarten, proliferation,
# Nearest to but: however, and, when, although, that, unless, he, until,
# Nearest to in: during, on, at, including, sternum, among, of, tanganyika,
# Nearest to known: used, well, such, stereotyped, nevis, regarded, aristocrats, peaking,
# Nearest to b: d, suing, mmo, morpheus, loya, gundobad, pt, lessened,
# Average loss at step 32000: 3.502139
# Average loss at step 34000: 3.494283
# Average loss at step 36000: 3.455300
# Average loss at step 38000: 3.302662
# Average loss at step 40000: 3.430470
# Nearest to four: six, three, five, seven, eight, two, nine, one,
# Nearest to i: ii, we, iii, you, he, they, t, it,
# Nearest to up: out, down, him, them, off, precisely, back, preparing,
# Nearest to at: on, during, in, ocp, viewpoints, prototypical, kelsey, cow,
# Nearest to it: he, she, there, this, they, which, what, not,
# Nearest to d: b, UNK, remixed, pt, cheerfully, im, cluster, heaters,
# Nearest to an: golgi, the, insulating, filius, summed, painkillers, tun, mung,
# Nearest to first: second, last, next, same, multipoint, prisma, duesberg, fourth,
# Nearest to while: however, when, before, although, where, though, pearlman, were,
# Nearest to during: after, at, in, lokasenna, under, when, keller, before,
# Nearest to zero: seven, five, nine, eight, six, three, four, two,
# Nearest to world: iff, insular, methyl, cavendish, tanzania, treasured, summer, universe,
# Nearest to but: however, although, and, which, when, that, though, somaliland,
# Nearest to in: of, during, and, at, for, within, karel, from,
# Nearest to known: used, such, well, regarded, possible, stereotyped, aristocrats, peaking,
# Nearest to b: d, UNK, c, suing, r, gundobad, sahih, lessened,
# Average loss at step 42000: 3.434379
# Average loss at step 44000: 3.452768
# Average loss at step 46000: 3.452308
# Average loss at step 48000: 3.351224
# Average loss at step 50000: 3.384739
# Nearest to four: six, seven, eight, five, three, nine, two, zero,
# Nearest to i: we, you, ii, they, iii, t, he, collett,
# Nearest to up: out, down, them, him, off, preparing, back, precisely,
# Nearest to at: during, near, on, towards, in, from, monarchy, infamously,
# Nearest to it: he, she, there, this, they, itself, now, actually,
# Nearest to d: b, m, f, matriculation, remixed, t, pt, im,
# Nearest to an: lk, palpitations, vim, insulating, filius, schoenberg, golgi, summed,
# Nearest to first: second, next, last, same, oldest, third, original, fourth,
# Nearest to while: when, however, although, though, before, where, but, after,
# Nearest to during: after, in, under, lokasenna, at, when, from, throughout,
# Nearest to zero: five, seven, four, eight, six, nine, three, two,
# Nearest to world: methyl, iff, lup, ti, hammerhead, summer, ecclestone, disabled,
# Nearest to but: however, although, and, than, when, though, while, that,
# Nearest to in: during, from, within, since, on, under, between, and,
# Nearest to known: used, regarded, such, well, possible, called, preserved, stereotyped,
# Nearest to b: d, c, socialists, alford, championed, lessened, oren, caso,
# Average loss at step 52000: 3.431996
# Average loss at step 54000: 3.428909
# Average loss at step 56000: 3.439204
# Average loss at step 58000: 3.394953
# Average loss at step 60000: 3.392634
# Nearest to four: five, seven, six, eight, three, nine, two, zero,
# Nearest to i: we, ii, you, they, iii, t, collett, domingo,
# Nearest to up: down, out, him, off, them, back, preparing, returns,
# Nearest to at: in, during, cheesemaking, eamon, infamously, lonnie, near, viewpoints,
# Nearest to it: he, she, there, this, they, now, generally, which,
# Nearest to d: b, m, t, rabbi, contralto, sainthood, matriculation, f,
# Nearest to an: insulating, filius, lk, booch, summed, rangers, lois, cybele,
# Nearest to first: second, last, next, same, siege, third, oldest, past,
# Nearest to while: although, before, when, though, however, after, earnhardt, dyes,
# Nearest to during: after, in, lokasenna, before, under, when, throughout, following,
# Nearest to zero: five, four, seven, eight, six, three, nine, two,
# Nearest to world: iff, insular, ti, universe, methyl, islamic, nation, post,
# Nearest to but: however, although, and, than, though, since, when, see,
# Nearest to in: within, during, at, of, since, from, among, including,
# Nearest to known: used, regarded, well, such, possible, considered, called, referred,
# Nearest to b: d, c, m, n, vcrs, r, alford, f,
# Average loss at step 62000: 3.241974
# Average loss at step 64000: 3.254920
# Average loss at step 66000: 3.405499
# Average loss at step 68000: 3.395389
# Average loss at step 70000: 3.360342
# Nearest to four: six, five, three, seven, eight, two, zero, nine,
# Nearest to i: we, ii, you, g, collett, they, ichij, iii,
# Nearest to up: down, out, off, him, back, them, preparing, away,
# Nearest to at: during, on, infamously, cheesemaking, prototypical, in, purer, fas,
# Nearest to it: he, she, there, this, they, still, usually, we,
# Nearest to d: b, m, contralto, cluster, rabbi, im, t, www,
# Nearest to an: booch, filius, pleasant, palpitations, tun, lois, oceania, huts,
# Nearest to first: second, last, next, original, third, same, fourth, oldest,
# Nearest to while: although, when, though, before, however, but, where, or,
# Nearest to during: after, before, throughout, in, within, at, lokasenna, under,
# Nearest to zero: five, six, four, eight, seven, nine, three, two,
# Nearest to world: iff, ti, post, flagella, universe, fated, signal, tiergarten,
# Nearest to but: however, although, though, while, and, than, which, until,
# Nearest to in: within, during, on, lutetium, for, from, through, controllable,
# Nearest to known: used, such, regarded, defined, well, considered, called, possible,
# Nearest to b: d, n, c, noxious, m, vcrs, f, h,
# Average loss at step 72000: 3.371838
# Average loss at step 74000: 3.347582
# Average loss at step 76000: 3.318792
# Average loss at step 78000: 3.348923
# Average loss at step 80000: 3.379499
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to i: you, ii, g, iii, we, they, collett, defences,
# Nearest to up: out, down, off, him, them, back, preparing, precisely,
# Nearest to at: in, on, cheesemaking, infamously, methylation, during, bidder, andromache,
# Nearest to it: he, she, there, this, they, we, nothing, never,
# Nearest to d: b, m, rabbi, f, cluster, www, im, contralto,
# Nearest to an: filius, laertius, lk, jarre, booch, rangers, lorenzo, wines,
# Nearest to first: second, last, next, third, same, fourth, past, symbiosis,
# Nearest to while: although, though, when, before, however, after, but, or,
# Nearest to during: after, in, before, throughout, when, despite, under, within,
# Nearest to zero: five, seven, six, four, eight, three, nine, two,
# Nearest to world: iff, universe, ti, nation, post, ecclestone, flagella, fated,
# Nearest to but: however, although, while, though, leanings, and, see, than,
# Nearest to in: during, within, on, at, among, until, of, with,
# Nearest to known: used, regarded, such, defined, called, referred, possible, considered,
# Nearest to b: d, c, m, oren, noxious, weierstrass, n, h,
# Average loss at step 82000: 3.402397
# Average loss at step 84000: 3.411004
# Average loss at step 86000: 3.390809
# Average loss at step 88000: 3.353928
# Average loss at step 90000: 3.362024
# Nearest to four: five, seven, six, three, eight, two, nine, zero,
# Nearest to i: you, we, ii, g, iii, t, collett, yemenite,
# Nearest to up: out, off, down, him, them, back, away, monophonic,
# Nearest to at: near, in, during, under, cheesemaking, topographic, on, hafez,
# Nearest to it: he, she, there, this, they, never, itself, actually,
# Nearest to d: b, fy, im, rabbi, m, kevin, chuppah, felons,
# Nearest to an: wines, intermarriage, figuratively, filius, pleasant, insulating, huts, tun,
# Nearest to first: second, last, next, earliest, third, final, symbiosis, fourth,
# Nearest to while: although, when, though, before, after, however, during, but,
# Nearest to during: after, in, throughout, before, under, until, through, within,
# Nearest to zero: five, seven, six, eight, four, nine, three, two,
# Nearest to world: post, universe, iff, empire, ecclestone, fated, nation, insular,
# Nearest to but: however, although, and, though, they, which, while, she,
# Nearest to in: during, within, under, at, with, near, from, of,
# Nearest to known: used, such, regarded, defined, called, possible, well, cited,
# Nearest to b: d, c, n, cm, h, disobeyed, m, noxious,
# Average loss at step 92000: 3.397341
# Average loss at step 94000: 3.256512
# Average loss at step 96000: 3.355163
# Average loss at step 98000: 3.238180
# Average loss at step 100000: 3.356955
# Nearest to four: six, seven, five, eight, three, two, nine, zero,
# Nearest to i: you, we, ii, g, iii, they, t, yemenite,
# Nearest to up: out, off, down, him, them, back, preparing, away,
# Nearest to at: near, during, on, in, reflects, cheesemaking, lanka, within,
# Nearest to it: he, she, this, they, there, nothing, never, what,
# Nearest to d: b, fy, marlins, ben, im, cluster, applicability, kevin,
# Nearest to an: figuratively, insulating, sparse, filius, lk, wines, conforming, another,
# Nearest to first: last, second, next, third, fourth, final, symbiosis, sins,
# Nearest to while: although, when, though, before, however, after, but, and,
# Nearest to during: after, in, throughout, before, under, within, despite, until,
# Nearest to zero: five, eight, six, four, seven, nine, two, three,
# Nearest to world: universe, post, ecclestone, ti, empire, nation, iff, sahara,
# Nearest to but: however, although, and, though, while, which, topmost, that,
# Nearest to in: during, within, of, on, from, until, despite, at,
# Nearest to known: used, regarded, such, defined, possible, considered, cited, well,
# Nearest to b: d, suing, etymologies, deanna, lewiston, patterson, internationalist, disobeyed,

# %%
num_points = 400

final_embeddings = np.asfarray( final_embeddings, dtype='float' )
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
